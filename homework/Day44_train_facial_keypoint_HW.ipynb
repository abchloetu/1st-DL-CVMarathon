# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\chloe\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\chloe\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\chloe\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 0.0066 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00226, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00226 to 0.00186, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00186
# Epoch 4/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00186
# Epoch 5/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00186 to 0.00178, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2593e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00178 to 0.00172, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.3219e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00172 to 0.00160, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 7.2279e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00160 to 0.00150, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 6.5435e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00150 to 0.00140, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.7098e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00140 to 0.00127, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 5.3626e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00127 to 0.00115, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.8339e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00115 to 0.00109, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.6358e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00109 to 0.00104, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.3101e-04 - val_loss: 9.8678e-04
#
# Epoch 00014: val_loss improved from 0.00104 to 0.00099, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.9792e-04 - val_loss: 9.6043e-04
#
# Epoch 00015: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.8822e-04 - val_loss: 9.6350e-04
#
# Epoch 00016: val_loss did not improve from 0.00096
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.6935e-04 - val_loss: 9.2024e-04
#
# Epoch 00017: val_loss improved from 0.00096 to 0.00092, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.4829e-04 - val_loss: 8.7942e-04
#
# Epoch 00018: val_loss improved from 0.00092 to 0.00088, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.4284e-04 - val_loss: 9.0078e-04
#
# Epoch 00019: val_loss did not improve from 0.00088
# Epoch 20/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 3.2766e-04 - val_loss: 9.1521e-04
#
# Epoch 00020: val_loss did not improve from 0.00088
# Epoch 21/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.2176e-04 - val_loss: 8.4470e-04
#
# Epoch 00021: val_loss improved from 0.00088 to 0.00084, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0839e-04 - val_loss: 8.9784e-04
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0374e-04 - val_loss: 9.0954e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.9790e-04 - val_loss: 8.2698e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8147e-04 - val_loss: 9.0160e-04
#
# Epoch 00025: val_loss did not improve from 0.00083
# Epoch 26/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7332e-04 - val_loss: 8.3522e-04
#
# Epoch 00026: val_loss did not improve from 0.00083
# Epoch 27/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7346e-04 - val_loss: 8.2193e-04
#
# Epoch 00027: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6634e-04 - val_loss: 8.2217e-04
#
# Epoch 00028: val_loss did not improve from 0.00082
# Epoch 29/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.5608e-04 - val_loss: 8.1809e-04
#
# Epoch 00029: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5247e-04 - val_loss: 8.2380e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4491e-04 - val_loss: 8.2135e-04
#
# Epoch 00031: val_loss did not improve from 0.00082
# Epoch 32/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3863e-04 - val_loss: 8.4172e-04
#
# Epoch 00032: val_loss did not improve from 0.00082
# Epoch 33/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4062e-04 - val_loss: 7.9206e-04
#
# Epoch 00033: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3472e-04 - val_loss: 8.0466e-04
#
# Epoch 00034: val_loss did not improve from 0.00079
# Epoch 35/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2686e-04 - val_loss: 7.7638e-04
#
# Epoch 00035: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2085e-04 - val_loss: 7.8247e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2237e-04 - val_loss: 7.8431e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.2280e-04 - val_loss: 7.8527e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.1375e-04 - val_loss: 7.9348e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1147e-04 - val_loss: 7.8369e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1693e-04 - val_loss: 7.6670e-04
#
# Epoch 00041: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1190e-04 - val_loss: 7.6342e-04
#
# Epoch 00042: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0330e-04 - val_loss: 7.7514e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9876e-04 - val_loss: 7.9485e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9712e-04 - val_loss: 7.6897e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9441e-04 - val_loss: 7.8824e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.9395e-04 - val_loss: 7.7640e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9218e-04 - val_loss: 7.6872e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9573e-04 - val_loss: 7.6059e-04
#
# Epoch 00049: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9249e-04 - val_loss: 7.9105e-04
#
# Epoch 00050: val_loss did not improve from 0.00076
# Epoch 51/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 1.9474e-04 - val_loss: 8.0371e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8068e-04 - val_loss: 8.1142e-04
#
# Epoch 00052: val_loss did not improve from 0.00076
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8067e-04 - val_loss: 7.6951e-04
#
# Epoch 00053: val_loss did not improve from 0.00076
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7623e-04 - val_loss: 7.7182e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6867e-04 - val_loss: 7.8549e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.7018e-04 - val_loss: 7.9206e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6789e-04 - val_loss: 7.9239e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6858e-04 - val_loss: 7.7159e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6486e-04 - val_loss: 7.5698e-04
#
# Epoch 00059: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6005e-04 - val_loss: 7.5281e-04
#
# Epoch 00060: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6046e-04 - val_loss: 7.6585e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5628e-04 - val_loss: 8.0388e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.6278e-04 - val_loss: 7.5652e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5713e-04 - val_loss: 7.6719e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5235e-04 - val_loss: 8.1285e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5638e-04 - val_loss: 7.7208e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5197e-04 - val_loss: 7.4795e-04
#
# Epoch 00067: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 68/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5223e-04 - val_loss: 7.7909e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5161e-04 - val_loss: 7.9481e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4823e-04 - val_loss: 7.6939e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4802e-04 - val_loss: 8.0444e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4439e-04 - val_loss: 7.8615e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4299e-04 - val_loss: 8.4259e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4395e-04 - val_loss: 7.5058e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4217e-04 - val_loss: 7.5868e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3992e-04 - val_loss: 7.8456e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3958e-04 - val_loss: 7.8058e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3436e-04 - val_loss: 7.5444e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3380e-04 - val_loss: 7.6575e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3664e-04 - val_loss: 7.5689e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3337e-04 - val_loss: 7.5977e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3494e-04 - val_loss: 7.7271e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3261e-04 - val_loss: 7.6071e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2934e-04 - val_loss: 7.7912e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3026e-04 - val_loss: 7.6826e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2959e-04 - val_loss: 7.9419e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2995e-04 - val_loss: 7.5753e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2768e-04 - val_loss: 7.3914e-04
#
# Epoch 00088: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 89/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3078e-04 - val_loss: 7.8062e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2171e-04 - val_loss: 7.4239e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2134e-04 - val_loss: 8.0032e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2353e-04 - val_loss: 7.7420e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2027e-04 - val_loss: 7.7712e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.2480e-04 - val_loss: 7.5879e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2389e-04 - val_loss: 7.3628e-04
#
# Epoch 00095: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 96/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1832e-04 - val_loss: 7.6015e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1752e-04 - val_loss: 7.6349e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1634e-04 - val_loss: 7.6931e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1703e-04 - val_loss: 7.2671e-04
#
# Epoch 00099: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 100/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1345e-04 - val_loss: 7.6014e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1266e-04 - val_loss: 7.9874e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1218e-04 - val_loss: 7.7287e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1187e-04 - val_loss: 7.6977e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1149e-04 - val_loss: 7.8552e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1468e-04 - val_loss: 7.6155e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1191e-04 - val_loss: 7.4298e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1336e-04 - val_loss: 7.7260e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0893e-04 - val_loss: 7.5737e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0934e-04 - val_loss: 7.5457e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0594e-04 - val_loss: 7.6298e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0536e-04 - val_loss: 7.8575e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0495e-04 - val_loss: 7.8972e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0466e-04 - val_loss: 7.5529e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0422e-04 - val_loss: 7.7282e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0368e-04 - val_loss: 7.6944e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0362e-04 - val_loss: 7.7742e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0071e-04 - val_loss: 7.9897e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0260e-04 - val_loss: 7.4304e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0211e-04 - val_loss: 7.5558e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0393e-04 - val_loss: 7.6321e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0173e-04 - val_loss: 7.6414e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0441e-04 - val_loss: 7.4445e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9510e-05 - val_loss: 7.8301e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7035e-05 - val_loss: 7.7442e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7586e-05 - val_loss: 7.7811e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6698e-05 - val_loss: 7.4113e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5137e-05 - val_loss: 7.6368e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8425e-05 - val_loss: 7.7830e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4823e-05 - val_loss: 7.8864e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3745e-05 - val_loss: 7.2968e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3367e-05 - val_loss: 7.6957e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7074e-05 - val_loss: 7.7812e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2859e-05 - val_loss: 7.5176e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5053e-05 - val_loss: 7.9988e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5117e-05 - val_loss: 7.7696e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3733e-05 - val_loss: 7.5956e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 9.4517e-05 - val_loss: 7.5566e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4722e-05 - val_loss: 7.4191e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 8.9860e-05 - val_loss: 7.3316e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9795e-05 - val_loss: 7.8929e-04
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9487e-05 - val_loss: 7.3453e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9664e-05 - val_loss: 7.5386e-04
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8718e-05 - val_loss: 7.5974e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.1365e-05 - val_loss: 7.6614e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2862e-05 - val_loss: 7.6367e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.0072e-05 - val_loss: 7.5369e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.7286e-05 - val_loss: 7.7568e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 8.7373e-05 - val_loss: 7.5662e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.5275e-05 - val_loss: 7.7602e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.9676e-05 - val_loss: 7.6105e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# C:\Users\chloe\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# C:\Users\chloe\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   if sys.path[0] == '':
# Epoch 1/20
# 66/66 [==============================] - 13s 204ms/step - loss: 0.0042 - val_loss: 0.0012
#
# Epoch 00001: val_loss did not improve from 0.00073
# Epoch 2/20
# 66/66 [==============================] - 12s 180ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00073
# Epoch 3/20
# 66/66 [==============================] - 12s 182ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00073
# Epoch 4/20
# 66/66 [==============================] - 12s 182ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00073
# Epoch 5/20
# 66/66 [==============================] - 11s 173ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00073
# Epoch 6/20
# 66/66 [==============================] - 12s 175ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00073
# Epoch 7/20
# 66/66 [==============================] - 12s 181ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00073
# Epoch 8/20
# 66/66 [==============================] - 12s 181ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00073
# Epoch 9/20
# 66/66 [==============================] - 12s 180ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00073
# Epoch 10/20
# 66/66 [==============================] - 12s 182ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00073
# Epoch 11/20
# 66/66 [==============================] - 12s 181ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00073
# Epoch 12/20
# 66/66 [==============================] - 12s 189ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00073
# Epoch 13/20
# 66/66 [==============================] - 12s 178ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00073
# Epoch 14/20
# 66/66 [==============================] - 13s 194ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00073
# Epoch 15/20
# 66/66 [==============================] - 11s 164ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00073
# Epoch 16/20
# 66/66 [==============================] - 11s 166ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00073
# Epoch 17/20
# 66/66 [==============================] - 11s 162ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00073
# Epoch 18/20
# 66/66 [==============================] - 11s 162ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00073
# Epoch 19/20
# 66/66 [==============================] - 12s 180ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00073
# Epoch 20/20
# 66/66 [==============================] - 11s 167ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# ### 官方解答

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 17s 5ms/step - loss: 0.0043 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00196, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00196 to 0.00193, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00184, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.5768e-04 - val_loss: 0.0017
#
# Epoch 00004: val_loss improved from 0.00184 to 0.00168, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 7.2265e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00168 to 0.00129, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 6.0382e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00129 to 0.00116, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 5.2541e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00116 to 0.00106, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.8018e-04 - val_loss: 9.9643e-04
#
# Epoch 00008: val_loss improved from 0.00106 to 0.00100, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 4.4228e-04 - val_loss: 9.5708e-04
#
# Epoch 00009: val_loss improved from 0.00100 to 0.00096, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.0667e-04 - val_loss: 8.9229e-04
#
# Epoch 00010: val_loss improved from 0.00096 to 0.00089, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.7920e-04 - val_loss: 8.8314e-04
#
# Epoch 00011: val_loss improved from 0.00089 to 0.00088, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.5325e-04 - val_loss: 8.4721e-04
#
# Epoch 00012: val_loss improved from 0.00088 to 0.00085, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 3.3547e-04 - val_loss: 9.0484e-04
#
# Epoch 00013: val_loss did not improve from 0.00085
# Epoch 14/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 3.3076e-04 - val_loss: 8.1564e-04
#
# Epoch 00014: val_loss improved from 0.00085 to 0.00082, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.0546e-04 - val_loss: 8.2493e-04
#
# Epoch 00015: val_loss did not improve from 0.00082
# Epoch 16/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.9069e-04 - val_loss: 7.5160e-04
#
# Epoch 00016: val_loss improved from 0.00082 to 0.00075, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.9127e-04 - val_loss: 7.6345e-04
#
# Epoch 00017: val_loss did not improve from 0.00075
# Epoch 18/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.7525e-04 - val_loss: 7.6623e-04
#
# Epoch 00018: val_loss did not improve from 0.00075
# Epoch 19/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.6415e-04 - val_loss: 7.7050e-04
#
# Epoch 00019: val_loss did not improve from 0.00075
# Epoch 20/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.6002e-04 - val_loss: 7.4278e-04
#
# Epoch 00020: val_loss improved from 0.00075 to 0.00074, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.5098e-04 - val_loss: 7.4095e-04
#
# Epoch 00021: val_loss improved from 0.00074 to 0.00074, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.5001e-04 - val_loss: 7.4589e-04
#
# Epoch 00022: val_loss did not improve from 0.00074
# Epoch 23/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.3965e-04 - val_loss: 7.3476e-04
#
# Epoch 00023: val_loss improved from 0.00074 to 0.00073, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.3078e-04 - val_loss: 7.2701e-04
#
# Epoch 00024: val_loss improved from 0.00073 to 0.00073, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.2764e-04 - val_loss: 7.2980e-04
#
# Epoch 00025: val_loss did not improve from 0.00073
# Epoch 26/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.2017e-04 - val_loss: 7.0946e-04
#
# Epoch 00026: val_loss improved from 0.00073 to 0.00071, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 2.1303e-04 - val_loss: 7.1288e-04
#
# Epoch 00027: val_loss did not improve from 0.00071
# Epoch 28/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.0995e-04 - val_loss: 7.1493e-04
#
# Epoch 00028: val_loss did not improve from 0.00071
# Epoch 29/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.0583e-04 - val_loss: 7.0699e-04
#
# Epoch 00029: val_loss improved from 0.00071 to 0.00071, saving model to best_weights_augment.h5
# Epoch 30/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.0228e-04 - val_loss: 7.0200e-04
#
# Epoch 00030: val_loss improved from 0.00071 to 0.00070, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.9834e-04 - val_loss: 7.3483e-04
#
# Epoch 00031: val_loss did not improve from 0.00070
# Epoch 32/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.9306e-04 - val_loss: 6.8538e-04
#
# Epoch 00032: val_loss improved from 0.00070 to 0.00069, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.9004e-04 - val_loss: 7.0985e-04
#
# Epoch 00033: val_loss did not improve from 0.00069
# Epoch 34/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.8713e-04 - val_loss: 7.0129e-04
#
# Epoch 00034: val_loss did not improve from 0.00069
# Epoch 35/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.8169e-04 - val_loss: 7.3197e-04
#
# Epoch 00035: val_loss did not improve from 0.00069
# Epoch 36/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.7961e-04 - val_loss: 7.0165e-04
#
# Epoch 00036: val_loss did not improve from 0.00069
# Epoch 37/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.7291e-04 - val_loss: 7.2304e-04
#
# Epoch 00037: val_loss did not improve from 0.00069
# Epoch 38/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.7140e-04 - val_loss: 6.8636e-04
#
# Epoch 00038: val_loss did not improve from 0.00069
# Epoch 39/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6699e-04 - val_loss: 6.9914e-04
#
# Epoch 00039: val_loss did not improve from 0.00069
# Epoch 40/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 1.6885e-04 - val_loss: 6.8206e-04
#
# Epoch 00040: val_loss improved from 0.00069 to 0.00068, saving model to best_weights_augment.h5
# Epoch 41/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6462e-04 - val_loss: 6.9359e-04
#
# Epoch 00041: val_loss did not improve from 0.00068
# Epoch 42/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.6453e-04 - val_loss: 6.8223e-04
#
# Epoch 00042: val_loss did not improve from 0.00068
# Epoch 43/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.6023e-04 - val_loss: 6.9881e-04
#
# Epoch 00043: val_loss did not improve from 0.00068
# Epoch 44/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.5757e-04 - val_loss: 6.6853e-04
#
# Epoch 00044: val_loss improved from 0.00068 to 0.00067, saving model to best_weights_augment.h5
# Epoch 45/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.5691e-04 - val_loss: 7.0097e-04
#
# Epoch 00045: val_loss did not improve from 0.00067
# Epoch 46/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.5799e-04 - val_loss: 6.6619e-04
#
# Epoch 00046: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.5650e-04 - val_loss: 6.9576e-04
#
# Epoch 00047: val_loss did not improve from 0.00067
# Epoch 48/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.5184e-04 - val_loss: 6.7126e-04
#
# Epoch 00048: val_loss did not improve from 0.00067
# Epoch 49/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.4625e-04 - val_loss: 7.2550e-04
#
# Epoch 00049: val_loss did not improve from 0.00067
# Epoch 50/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.4581e-04 - val_loss: 6.5683e-04
#
# Epoch 00050: val_loss improved from 0.00067 to 0.00066, saving model to best_weights_augment.h5
# Epoch 51/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.4204e-04 - val_loss: 6.6330e-04
#
# Epoch 00051: val_loss did not improve from 0.00066
# Epoch 52/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.4213e-04 - val_loss: 6.7831e-04
#
# Epoch 00052: val_loss did not improve from 0.00066
# Epoch 53/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3600e-04 - val_loss: 7.2950e-04
#
# Epoch 00053: val_loss did not improve from 0.00066
# Epoch 54/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3624e-04 - val_loss: 6.7623e-04
#
# Epoch 00054: val_loss did not improve from 0.00066
# Epoch 55/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3455e-04 - val_loss: 6.7215e-04
#
# Epoch 00055: val_loss did not improve from 0.00066
# Epoch 56/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3388e-04 - val_loss: 7.3321e-04
#
# Epoch 00056: val_loss did not improve from 0.00066
# Epoch 57/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3284e-04 - val_loss: 7.0713e-04
#
# Epoch 00057: val_loss did not improve from 0.00066
# Epoch 58/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2911e-04 - val_loss: 6.6243e-04
#
# Epoch 00058: val_loss did not improve from 0.00066
# Epoch 59/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.3039e-04 - val_loss: 7.0785e-04
#
# Epoch 00059: val_loss did not improve from 0.00066
# Epoch 60/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3061e-04 - val_loss: 6.8595e-04
#
# Epoch 00060: val_loss did not improve from 0.00066
# Epoch 61/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.3068e-04 - val_loss: 7.0698e-04
#
# Epoch 00061: val_loss did not improve from 0.00066
# Epoch 62/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2686e-04 - val_loss: 6.7337e-04
#
# Epoch 00062: val_loss did not improve from 0.00066
# Epoch 63/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2499e-04 - val_loss: 6.8376e-04
#
# Epoch 00063: val_loss did not improve from 0.00066
# Epoch 64/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2194e-04 - val_loss: 6.7096e-04
#
# Epoch 00064: val_loss did not improve from 0.00066
# Epoch 65/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2341e-04 - val_loss: 6.6757e-04
#
# Epoch 00065: val_loss did not improve from 0.00066
# Epoch 66/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.2213e-04 - val_loss: 7.0048e-04
#
# Epoch 00066: val_loss did not improve from 0.00066
# Epoch 67/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1899e-04 - val_loss: 7.2089e-04
#
# Epoch 00067: val_loss did not improve from 0.00066
# Epoch 68/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1757e-04 - val_loss: 6.7655e-04
#
# Epoch 00068: val_loss did not improve from 0.00066
# Epoch 69/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1831e-04 - val_loss: 6.7578e-04
#
# Epoch 00069: val_loss did not improve from 0.00066
# Epoch 70/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1811e-04 - val_loss: 6.7988e-04
#
# Epoch 00070: val_loss did not improve from 0.00066
# Epoch 71/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1778e-04 - val_loss: 7.1361e-04
#
# Epoch 00071: val_loss did not improve from 0.00066
# Epoch 72/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1537e-04 - val_loss: 6.7656e-04
#
# Epoch 00072: val_loss did not improve from 0.00066
# Epoch 73/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.1186e-04 - val_loss: 6.7227e-04
#
# Epoch 00073: val_loss did not improve from 0.00066
# Epoch 74/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1339e-04 - val_loss: 6.7771e-04
#
# Epoch 00074: val_loss did not improve from 0.00066
# Epoch 75/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1152e-04 - val_loss: 6.6901e-04
#
# Epoch 00075: val_loss did not improve from 0.00066
# Epoch 76/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0977e-04 - val_loss: 6.8259e-04
#
# Epoch 00076: val_loss did not improve from 0.00066
# Epoch 77/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.1044e-04 - val_loss: 6.7824e-04
#
# Epoch 00077: val_loss did not improve from 0.00066
# Epoch 78/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0685e-04 - val_loss: 6.9330e-04
#
# Epoch 00078: val_loss did not improve from 0.00066
# Epoch 79/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0627e-04 - val_loss: 6.7275e-04
#
# Epoch 00079: val_loss did not improve from 0.00066
# Epoch 80/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0784e-04 - val_loss: 6.8822e-04
#
# Epoch 00080: val_loss did not improve from 0.00066
# Epoch 81/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 1.0689e-04 - val_loss: 6.9212e-04
#
# Epoch 00081: val_loss did not improve from 0.00066
# Epoch 82/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0615e-04 - val_loss: 6.7539e-04
#
# Epoch 00082: val_loss did not improve from 0.00066
# Epoch 83/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0598e-04 - val_loss: 6.7990e-04
#
# Epoch 00083: val_loss did not improve from 0.00066
# Epoch 84/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0423e-04 - val_loss: 6.7427e-04
#
# Epoch 00084: val_loss did not improve from 0.00066
# Epoch 85/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0239e-04 - val_loss: 6.7721e-04
#
# Epoch 00085: val_loss did not improve from 0.00066
# Epoch 86/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0164e-04 - val_loss: 6.8332e-04
#
# Epoch 00086: val_loss did not improve from 0.00066
# Epoch 87/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0343e-04 - val_loss: 6.6424e-04
#
# Epoch 00087: val_loss did not improve from 0.00066
# Epoch 88/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.9705e-05 - val_loss: 6.8255e-04
#
# Epoch 00088: val_loss did not improve from 0.00066
# Epoch 89/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0148e-04 - val_loss: 6.7547e-04
#
# Epoch 00089: val_loss did not improve from 0.00066
# Epoch 90/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0022e-04 - val_loss: 6.7895e-04
#
# Epoch 00090: val_loss did not improve from 0.00066
# Epoch 91/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0312e-04 - val_loss: 6.9551e-04
#
# Epoch 00091: val_loss did not improve from 0.00066
# Epoch 92/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0230e-04 - val_loss: 6.7354e-04
#
# Epoch 00092: val_loss did not improve from 0.00066
# Epoch 93/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.9622e-05 - val_loss: 6.7082e-04
#
# Epoch 00093: val_loss did not improve from 0.00066
# Epoch 94/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.6869e-05 - val_loss: 6.7119e-04
#
# Epoch 00094: val_loss did not improve from 0.00066
# Epoch 95/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.7202e-05 - val_loss: 7.1094e-04
#
# Epoch 00095: val_loss did not improve from 0.00066
# Epoch 96/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.7076e-05 - val_loss: 6.8153e-04
#
# Epoch 00096: val_loss did not improve from 0.00066
# Epoch 97/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.0581e-04 - val_loss: 6.8277e-04
#
# Epoch 00097: val_loss did not improve from 0.00066
# Epoch 98/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.8834e-05 - val_loss: 6.7717e-04
#
# Epoch 00098: val_loss did not improve from 0.00066
# Epoch 99/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.6219e-05 - val_loss: 6.7018e-04
#
# Epoch 00099: val_loss did not improve from 0.00066
# Epoch 100/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.3898e-05 - val_loss: 6.6041e-04
#
# Epoch 00100: val_loss did not improve from 0.00066
# Epoch 101/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 9.3517e-05 - val_loss: 6.6600e-04
#
# Epoch 00101: val_loss did not improve from 0.00066
# Epoch 102/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.3364e-05 - val_loss: 7.0268e-04
#
# Epoch 00102: val_loss did not improve from 0.00066
# Epoch 103/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 9.4300e-05 - val_loss: 6.5582e-04
#
# Epoch 00103: val_loss improved from 0.00066 to 0.00066, saving model to best_weights_augment.h5
# Epoch 104/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.4150e-05 - val_loss: 6.5252e-04
#
# Epoch 00104: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 105/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.2128e-05 - val_loss: 6.6186e-04
#
# Epoch 00105: val_loss did not improve from 0.00065
# Epoch 106/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 9.1347e-05 - val_loss: 6.9146e-04
#
# Epoch 00106: val_loss did not improve from 0.00065
# Epoch 107/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.2020e-05 - val_loss: 6.7709e-04
#
# Epoch 00107: val_loss did not improve from 0.00065
# Epoch 108/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 9.0923e-05 - val_loss: 6.8990e-04
#
# Epoch 00108: val_loss did not improve from 0.00065
# Epoch 109/150
# 3424/3424 [==============================] - 16s 5ms/step - loss: 8.9353e-05 - val_loss: 6.6369e-04
#
# Epoch 00109: val_loss did not improve from 0.00065
# Epoch 110/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.9298e-05 - val_loss: 6.6903e-04
#
# Epoch 00110: val_loss did not improve from 0.00065
# Epoch 111/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.8242e-05 - val_loss: 6.6963e-04
#
# Epoch 00111: val_loss did not improve from 0.00065
# Epoch 112/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.0367e-05 - val_loss: 6.8669e-04
#
# Epoch 00112: val_loss did not improve from 0.00065
# Epoch 113/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.1247e-05 - val_loss: 6.9328e-04
#
# Epoch 00113: val_loss did not improve from 0.00065
# Epoch 114/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.1389e-05 - val_loss: 6.5869e-04
#
# Epoch 00114: val_loss did not improve from 0.00065
# Epoch 115/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.8534e-05 - val_loss: 6.8100e-04
#
# Epoch 00115: val_loss did not improve from 0.00065
# Epoch 116/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.0807e-05 - val_loss: 6.7509e-04
#
# Epoch 00116: val_loss did not improve from 0.00065
# Epoch 117/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 9.0008e-05 - val_loss: 6.8916e-04
#
# Epoch 00117: val_loss did not improve from 0.00065
# Epoch 118/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.8623e-05 - val_loss: 6.9747e-04
#
# Epoch 00118: val_loss did not improve from 0.00065
# Epoch 119/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.6948e-05 - val_loss: 6.6725e-04
#
# Epoch 00119: val_loss did not improve from 0.00065
# Epoch 120/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.5618e-05 - val_loss: 6.8824e-04
#
# Epoch 00120: val_loss did not improve from 0.00065
# Epoch 121/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.6470e-05 - val_loss: 6.8258e-04
#
# Epoch 00121: val_loss did not improve from 0.00065
# Epoch 122/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.8969e-05 - val_loss: 6.7855e-04
#
# Epoch 00122: val_loss did not improve from 0.00065
# Epoch 123/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5737e-05 - val_loss: 6.6818e-04
#
# Epoch 00123: val_loss did not improve from 0.00065
# Epoch 124/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.5697e-05 - val_loss: 6.7853e-04
#
# Epoch 00124: val_loss did not improve from 0.00065
# Epoch 125/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5221e-05 - val_loss: 6.7944e-04
#
# Epoch 00125: val_loss did not improve from 0.00065
# Epoch 126/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.5142e-05 - val_loss: 6.6804e-04
#
# Epoch 00126: val_loss did not improve from 0.00065
# Epoch 127/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 8.5261e-05 - val_loss: 6.7924e-04
#
# Epoch 00127: val_loss did not improve from 0.00065
# Epoch 128/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5360e-05 - val_loss: 6.8921e-04
#
# Epoch 00128: val_loss did not improve from 0.00065
# Epoch 129/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.6630e-05 - val_loss: 6.7275e-04
#
# Epoch 00129: val_loss did not improve from 0.00065
# Epoch 130/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.6294e-05 - val_loss: 6.9502e-04
#
# Epoch 00130: val_loss did not improve from 0.00065
# Epoch 131/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.4205e-05 - val_loss: 6.7484e-04
#
# Epoch 00131: val_loss did not improve from 0.00065
# Epoch 132/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.6921e-05 - val_loss: 6.6499e-04
#
# Epoch 00132: val_loss did not improve from 0.00065
# Epoch 133/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.4846e-05 - val_loss: 6.8062e-04
#
# Epoch 00133: val_loss did not improve from 0.00065
# Epoch 134/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3971e-05 - val_loss: 6.9005e-04
#
# Epoch 00134: val_loss did not improve from 0.00065
# Epoch 135/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5511e-05 - val_loss: 6.7826e-04
#
# Epoch 00135: val_loss did not improve from 0.00065
# Epoch 136/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3649e-05 - val_loss: 6.6530e-04
#
# Epoch 00136: val_loss did not improve from 0.00065
# Epoch 137/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.5290e-05 - val_loss: 6.8411e-04
#
# Epoch 00137: val_loss did not improve from 0.00065
# Epoch 138/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3333e-05 - val_loss: 6.4900e-04
#
# Epoch 00138: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 139/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3286e-05 - val_loss: 6.5740e-04
#
# Epoch 00139: val_loss did not improve from 0.00065
# Epoch 140/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.1910e-05 - val_loss: 6.7783e-04
#
# Epoch 00140: val_loss did not improve from 0.00065
# Epoch 141/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.3395e-05 - val_loss: 7.0384e-04
# Epoch 00141: val_loss did not improve from 0.00065
# Epoch 142/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.3561e-05 - val_loss: 6.7380e-04
#
# Epoch 00142: val_loss did not improve from 0.00065
# Epoch 143/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.1620e-05 - val_loss: 6.6955e-04
#
# Epoch 00143: val_loss did not improve from 0.00065
# Epoch 144/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.0150e-05 - val_loss: 6.8252e-04
#
# Epoch 00144: val_loss did not improve from 0.00065
# Epoch 145/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.3576e-05 - val_loss: 6.6702e-04
#
# Epoch 00145: val_loss did not improve from 0.00065
# Epoch 146/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.2332e-05 - val_loss: 6.6202e-04
#
# Epoch 00146: val_loss did not improve from 0.00065
# Epoch 147/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.0417e-05 - val_loss: 6.8768e-04
#
# Epoch 00147: val_loss did not improve from 0.00065
# Epoch 148/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.0805e-05 - val_loss: 6.7251e-04
#
# Epoch 00148: val_loss did not improve from 0.00065
# Epoch 149/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 8.3371e-05 - val_loss: 6.9390e-04
#
# Epoch 00149: val_loss did not improve from 0.00065
# Epoch 150/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 8.2844e-05 - val_loss: 6.9280e-04
#
# Epoch 00150: val_loss did not improve from 0.00065

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
